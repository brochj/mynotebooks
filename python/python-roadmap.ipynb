# %% [markdown]
# # Python Roadmap by Brock
#
#
# ## Links
# - [Programiz](https://www.programiz.com/python-programming)
#     - Tem uma ordem boa para aprender
#
# ## Basic
# - Variables
# - Conditions
# - Chained Conditionals
# - Operators
# - Typecasting
# - Control Flow (If/Else)
# - Loops and Iterables
# - Basic Data Structures
# - Functions
# - Mutable vs Immutable (Data Types)
# - Common Methods (string methods, list methods, etc)
# - File IO (how to read and write files)
# - Exception handling
#
# ## Intermediate
# - Object Oriented Programming (good practices)
# - Data Structures (Q, hash maps, stacks etc)
# - Built-in Data Structures
# - Comprehensions (List and Dict)
# - List, Dictionaries & Tuples
# - Lambda Functions
# - Map, Filter
# - Collections (built-in module)
# - *args & **kwargs
# - Inheritance OOP, polimorphism etc
# - Dunder Methods (advanced Class Behavior)
# - Regular Expressions
# - PIP e Python Package Index
# - Environments (virtualenv, Conda, Docker, Poetry(Pypi) , Pipenv)
# - Python Standard Library ( get familiar with'em)
# - Modules (create your own module)
# - Async IO
# - Python Interpreters (Eg: iroPython, Cpython, Jython, etc)
# - OOP vs FunctionalProgramming
# - PEPs
# - Type annotations ( built-in typing module) (MUST!!!)
# - Type annotations with MyPy
#
# ## Advanced
# - Decorators
# - Generators
# - Context Managers
# - Metaclasses
# - Concurrency (must study when you need performance)
# - Parallelism (must study when you need performance)
# - Testing (unit, etc)
# - Packages
#
# ## Master
# - Cython (must study when you need performance)
#
#
# ## Computer Science (Must know for big companies)
# #### Six mon to 1 year
# These are important!!, they are the fundamentals, so the don't change
# - Algorithms (Tools to solve common problems, like sorting, tree traversal, path finder,  etc)
# - Data Structures ( With Bad data strutures can increase cost and time)
# - Time Complexity
# - Space/memory Complexity
#
# ## CI/CD
# - Travis CI
# - Jenkis
# - Gitlab CI
# - Circle CI
#
# ## Popular Libraries
# - Asyncio (Must know for WebDev)
# - Pillow
# - Requests
# - Tkinter (Desktop GUI)
# - Six
# - PyQT  (Desktop GUI)
# - Pygame
#
#
# # Career Options
# ## Web Development
# - Django (1 month+) more professional
# - Flask (like Express)
# - ASGI vs WSGI
# - Celery
#
# ## Web Parsing/Scraping/Crawling
# - Bs4
# - Scrapy
#
# ## Test Automation
# - PyTest
# - Selenium (Browser Automation)
# - Robot Framework (more Professional)
# - unittest
#
# ## Scripting
# - System Admin (automations, configurations, ansible)
# - DevOps (o cara que faz o código chegar ao deploy, tabalha com AWS
# - Anything
#
# ## Data Science/Analysis
# - NumPy, Pandas, SciPy, Seaborn, Matplotlib, Bokeh
#
# ## Machine Learning
# - TensorFlow (Google) Usage more real-world
# - Scikit-Learn
# - Keras (runs TensorFlow on its background, so it's more intuitve
# - PyTorch (Facebook) Usage more Academic
